# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378 import *
# Out:
# Version:  0.0.4

# %% [markdown]
# <img src="https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Fc2a3dff0-8888-4234-b486-3261fc68048a%2FUntitled.png?table=block&id=31162417-4faf-4040-a1c0-fc9aad1efd07&spaceId=5be595e1-25d4-4a3a-bd62-c8ad048d296c&width=3500&userId=653932eb-4cdb-4072-b378-015bc8a4a981&cache=v2">

# %%
def factorial(N):
    value=1
    for i in range(1,N+1):
        value=value*i
    return value

# %%
def approx_sine(x,order=3):
    pass  #fill this in

# %%
x=.2

# %%
order=7

# %%
value=0
sign=1
for n in range(1,order+1,2):
    term=sign*x**n/factorial(n)
    value=value+term
    
    print(n,sign,term,value)
    
    sign=sign*-1. # reverse the sign of the term
# Out:
# 1 1 0.2 0.2
# 3 -1.0 -0.0013333333333333337 0.19866666666666669
# 5 1.0 2.6666666666666673e-06 0.19866933333333336
# 7 -1.0 -2.5396825396825407e-09 0.19866933079365082

# %%
def approx_sine(x,order=3):
    value=0
    sign=1
    for n in range(1,order+1,2):
        term=sign*x**n/factorial(n)
        value=value+term
        sign=sign*-1. # reverse the sign of the term
    
    return value

# %%
approx_sine(2,order=11)
# Out:
# 0.9092961359628027

# %%
sin(2)
# Out:
# 0.9092974268256817

# %%
linspace(0,5,7)
# Out:
# array([0.        , 0.83333333, 1.66666667, 2.5       , 3.33333333,
#        4.16666667, 5.        ])

# %%
x=linspace(0,2*pi,100)
y=sin(x)
plot(x,y)

y2=approx_sine(x)
plot(x,y2)

y2=approx_sine(x,order=7)
plot(x,y2)


y2=approx_sine(x,order=13)
plot(x,y2)

ylim([-1.1,1.1])
# Out:
# (-1.1, 1.1)
