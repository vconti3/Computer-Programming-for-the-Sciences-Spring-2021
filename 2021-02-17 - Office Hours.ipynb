# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sci378.mplturtle import *
# Out:
# Version:  0.0.4

# %%
reset()

for i in range(180):
    forward(100)
    backward(100)
    right(2)

    if i>10:
        pencolor("red")
