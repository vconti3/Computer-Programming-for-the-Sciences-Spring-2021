# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from  mplturtle import *

# %%
from mplturtle import reset,forward,right,left,animate

# %%
reset()

forward(30)
right(100)
forward(30)
left(50)

animate()

# %%
reset()

for i in range(20):
    forward(30)
    right(100)
    forward(30)
    left(50)

animate()

# %%
a=2
print(a)
if a>3:
    print("big")
    print("something else")
else:
    print("small")
    print("another")
    
print("end")
# Out:
# 2
# small
# another
# end

# %%
for a in range(6):
    print(a)
    if a>3:
        print("big")
        print("something else")
    else:
        print("small")
        print("another")
# Out:
# 0
# small
# another
# 1
# small
# another
# 2
# small
# another
# 3
# small
# another
# 4
# big
# something else
# 5
# big
# something else

# %%
reset()
for a in range(10):
    forward(50)
    if a>3:
        right(30)
    else:
        left(30)
animate()

# %%
a=6

a=a+1

# %%
a
# Out:
# 7
